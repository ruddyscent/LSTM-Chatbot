# %% [markdown]
# # LSTM Bot
#
# ## Project Overview
#
# In this project, you will build a chatbot that can converse with you at the command line. The chatbot will use a Sequence to Sequence text generation architecture with an LSTM as it's memory unit. You will also learn to use pretrained word embeddings to improve the performance of the model. At the conclusion of the project, you will be able to show your chatbot to potential employers.
#
# Additionally, you have the option to use pretrained word embeddings in your model. We have loaded Brown Embeddings from Gensim in the starter code below. You can compare the performance of your model with pre-trained embeddings against a model without the embeddings.
#
#
#
# ---
#
#
#
# A sequence to sequence model (Seq2Seq) has two components:
# - An Encoder consisting of an embedding layer and LSTM unit.
# - A Decoder consisting of an embedding layer, LSTM unit, and linear output unit.
#
# The Seq2Seq model works by accepting an input into the Encoder, passing the hidden state from the Encoder to the Decoder, which the Decoder uses to output a series of token predictions.
#
# ## Dependencies
#
# - Pytorch
# - Numpy
# - Pandas
# - NLTK
# - Gzip
# - Gensim
#
#
# Please choose a dataset from the Torchtext website. We recommend looking at the Squad dataset first. Here is a link to the website where you can view your options:
#
# - https://pytorch.org/text/stable/datasets.html

# %%
# !pip install torchdata==0.3.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchdata==0.3.0 in /root/.local/lib/python3.7/site-packages (0.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from torchdata==0.3.0) (2.23.0)
# Requirement already satisfied: urllib3>=1.25 in /opt/conda/lib/python3.7/site-packages (from torchdata==0.3.0) (1.25.7)
# Collecting torch==1.11.0
#   Using cached torch-1.11.0-cp37-cp37m-manylinux1_x86_64.whl (750.6 MB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->torchdata==0.3.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->torchdata==0.3.0) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->torchdata==0.3.0) (2.9)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from torch==1.11.0->torchdata==0.3.0) (3.7.4.1)
# ERROR: torchvision 0.8.2+cu110 has requirement torch==1.7.1, but you'll have torch 1.11.0 which is incompatible.
# ERROR: torchaudio 0.7.2 has requirement torch==1.7.1, but you'll have torch 1.11.0 which is incompatible.
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.1+cu110
#     Uninstalling torch-1.7.1+cu110:
#       Successfully uninstalled torch-1.7.1+cu110
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed torch-1.11.0

# %%
# !nvidia-smi
# Out:
# Sun Apr 16 16:46:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.06    Driver Version: 450.51.06    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import gensim
import nltk
import numpy as np
import pandas as pd
import gzip
import torch
from nltk.corpus import brown
from nltk.tokenize import RegexpTokenizer
import torch.nn as nn
from sklearn.model_selection import KFold
import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
torch.__version__
# Out:
# '1.11.0+cu102'

# %%
torch.__version__
# Out:
# '1.7.1+cu110'

# %%
torch.__version__
# Out:
# '1.11.0+cu102'

# %%
nltk.download('brown')
nltk.download('punkt')

# Output, save, and load brown embeddings

model = gensim.models.Word2Vec(brown.sents())
model.save('brown.embedding')

w2v = gensim.models.Word2Vec.load('brown.embedding')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def loadDF():
    '''
  
    You will use this function to load the dataset into a Pandas Dataframe for processing.

    '''
    from torchtext.datasets import SQuAD1
    train_iter, dev_iter = SQuAD1()
    
    train_and_dev_data = []
    
    for example in train_iter:
        data = {
#             "context": example[0],
            "question": example[1].lower().strip(),
            "answer": example[2][0].lower().strip(),
#             "answer_start": example[3]
        }
        train_and_dev_data.append(data)
    
    for example in dev_iter:
        data = {
#             "context": example[0],
            "question": example[1].lower().strip(),
            "answer": example[2][0].lower().strip(),
#             "answer_start": example[3]
        }
        train_and_dev_data.append(data)
        
    
    df = pd.DataFrame(train_and_dev_data)

    return df

# %%
def prepare_text(sentence):
    
    '''

    Our text needs to be cleaned with a tokenizer. This function will perform that task.
    https://www.nltk.org/api/nltk.tokenize.html

    '''
    
#     vocab = Vocab(name='Vocabulary')

#     tokens = vocab.cleanText(sentence)
    tokens = nltk.tokenize.RegexpTokenizer(r'\w+').tokenize(sentence)
    
    return tokens

# %%
data_df = loadDF()

# %%
#delete rows with empty "answer" column - they cause an error during training process
data_df = data_df.drop(axis=1, index=[55764, 27633])

# %%
data_df.head(10)
# Out:
#                                             question  \
# 0  to whom did the virgin mary allegedly appear i...
# 1  what is in front of the notre dame main building?
# 2  the basilica of the sacred heart at notre dame...
# 3                  what is the grotto at notre dame?
# 4  what sits on top of the main building at notre...
# 5  when did the scholastic magazine of notre dame...
# 6   how often is notre dame's the juggler published?
# 7  what is the daily student paper at notre dame ...
# 8  how many student news papers are found at notr...
# 9  in what year did the student paper common sens...
#
#                                     answer
# 0               saint bernadette soubirous
# 1                a copper statue of christ
# 2                        the main building
# 3  a marian place of prayer and reflection
# 4       a golden statue of the virgin mary
# 5                           september 1876
# 6                                    twice
# 7                             the observer
# 8                                    three
# 9                                     1987

# %%
data_df['question'] = data_df['question'].apply(prepare_text)
data_df['answer'] = data_df['answer'].apply(prepare_text)
data_df.head(10)
# Out:
#                                             question  \
# 0  [to, whom, did, the, virgin, mary, allegedly, ...
# 1  [what, is, in, front, of, the, notre, dame, ma...
# 2  [the, basilica, of, the, sacred, heart, at, no...
# 3           [what, is, the, grotto, at, notre, dame]
# 4  [what, sits, on, top, of, the, main, building,...
# 5  [when, did, the, scholastic, magazine, of, not...
# 6  [how, often, is, notre, dame, s, the, juggler,...
# 7  [what, is, the, daily, student, paper, at, not...
# 8  [how, many, student, news, papers, are, found,...
# 9  [in, what, year, did, the, student, paper, com...
#
#                                             answer
# 0                   [saint, bernadette, soubirous]
# 1                  [a, copper, statue, of, christ]
# 2                            [the, main, building]
# 3  [a, marian, place, of, prayer, and, reflection]
# 4       [a, golden, statue, of, the, virgin, mary]
# 5                                [september, 1876]
# 6                                          [twice]
# 7                                  [the, observer]
# 8                                          [three]
# 9                                           [1987]

# %%
# first we are creating a Vocab Class
class Vocab:
    def __init__(self, name):
        self.name = name
        self.index = {}
        self.count = 0
        self.words = {}

    # This function cleans our words before adding them
    def cleanText(self, text):
        tokenizer = RegexpTokenizer(r'\w+')
        text = tokenizer.tokenize(text)
        return text
    
    # This function indexes words in our vocabulary
    def indexWord(self, word):
#         for word in sentence.split(" "):
        if word not in self.words:
            self.words[word] = self.count
            self.index[self.count] = word
            self.count += 1




def build_vocabularies(df):
    '''
    Input: df: pd.dataframe with data,  
    Output: q_vocab, a_vocab: objects of class Vocab for questions ans answers
    Function will build vocabularies for question and answers or "source" and "target"
    '''
    
#     for row in data_df.iterrows():
#         q_vocab.indexWord(" ".join(row[1][0]))
#         a_vocab.indexWord(" ".join(row[1][1]))
        
    q_vocab = Vocab(name='Question_Vocabulary')
    a_vocab = Vocab(name='Answer_Vocabulary')
    
    count_q = 0
    count_a = 0
    for i, r in df.iterrows():
        text_q = []
        text_a = []    
        text_q = r['question']
        text_a = r['answer']
        for t in text_q:
            if count_q % 1000 == 0:
                print("Adding word {} to our question vocabulary.".format(count_q))
            q_vocab.indexWord(t)
            count_q += 1
            
        for t in text_a:
            if count_a % 1000 == 0:
                print("Adding word {} to our answer vocabulary.".format(count_a))
            a_vocab.indexWord(t)
            count_a += 1

            
    return q_vocab, a_vocab

# %%
q_v, a_v = build_vocabularies(data_df)
# Out:
# Adding word 0 to our question vocabulary.
# Adding word 0 to our answer vocabulary.
# Adding word 1000 to our question vocabulary.
# Adding word 2000 to our question vocabulary.
# Adding word 3000 to our question vocabulary.
# Adding word 4000 to our question vocabulary.
# Adding word 1000 to our answer vocabulary.
# Adding word 5000 to our question vocabulary.
# Adding word 6000 to our question vocabulary.
# Adding word 7000 to our question vocabulary.
# Adding word 8000 to our question vocabulary.
# Adding word 2000 to our answer vocabulary.
# Adding word 9000 to our question vocabulary.
# Adding word 10000 to our question vocabulary.
# Adding word 11000 to our question vocabulary.
# Adding word 12000 to our question vocabulary.
# Adding word 3000 to our answer vocabulary.
# Adding word 13000 to our question vocabulary.
# Adding word 14000 to our question vocabulary.
# Adding word 15000 to our question vocabulary.
# Adding word 4000 to our answer vocabulary.
# Adding word 16000 to our question vocabulary.
# Adding word 17000 to our question vocabulary.
# Adding word 18000 to our question vocabulary.
# Adding word 19000 to our question vocabulary.
# Adding word 20000 to our question vocabulary.
# Adding word 5000 to our answer vocabulary.
# Adding word 21000 to our question vocabulary.
# Adding word 22000 to our question vocabulary.
# Adding word 23000 to our question vocabulary.
# Adding word 24000 to our question vocabulary.
# Adding word 6000 to our answer vocabulary.
# Adding word 25000 to our question vocabulary.
# Adding word 26000 to our question vocabulary.
# Adding word 27000 to our question vocabulary.
# Adding word 28000 to our question vocabulary.
# Adding word 7000 to our answer vocabulary.
# Adding word 29000 to our question vocabulary.
# Adding word 30000 to our question vocabulary.
# Adding word 31000 to our question vocabulary.
# Adding word 32000 to our question vocabulary.
# Adding word 33000 to our question vocabulary.
# Adding word 8000 to our answer vocabulary.
# Adding word 34000 to our question vocabulary.
# Adding word 35000 to our question vocabulary.
# Adding word 36000 to our question vocabulary.
# Adding word 9000 to our answer vocabulary.
# Adding word 37000 to our question vocabulary.
# Adding word 38000 to our question vocabulary.
# Adding word 39000 to our question vocabulary.
# Adding word 40000 to our question vocabulary.
# Adding word 10000 to our answer vocabulary.
# Adding word 41000 to our question vocabulary.
# Adding word 42000 to our question vocabulary.
# Adding word 43000 to our question vocabulary.
# Adding word 44000 to our question vocabulary.
# Adding word 45000 to our question vocabulary.
# Adding word 11000 to our answer vocabulary.
# Adding word 46000 to our question vocabulary.
# Adding word 47000 to our question vocabulary.
# Adding word 48000 to our question vocabulary.
# Adding word 49000 to our question vocabulary.
# Adding word 50000 to our question vocabulary.
# Adding word 12000 to our answer vocabulary.
# Adding word 51000 to our question vocabulary.
# Adding word 52000 to our question vocabulary.
# Adding word 13000 to our answer vocabulary.
# Adding word 53000 to our question vocabulary.
# Adding word 54000 to our question vocabulary.
# Adding word 14000 to our answer vocabulary.
# Adding word 55000 to our question vocabulary.
# Adding word 56000 to our question vocabulary.
# Adding word 57000 to our question vocabulary.
# Adding word 15000 to our answer vocabulary.
# Adding word 58000 to our question vocabulary.
# Adding word 59000 to our question vocabulary.
# Adding word 16000 to our answer vocabulary.
# Adding word 60000 to our question vocabulary.
# Adding word 17000 to our answer vocabulary.
# Adding word 61000 to our question vocabulary.
# Adding word 62000 to our question vocabulary.
# Adding word 63000 to our question vocabulary.
# Adding word 64000 to our question vocabulary.
# Adding word 65000 to our question vocabulary.
# Adding word 18000 to our answer vocabulary.
# Adding word 66000 to our question vocabulary.
# Adding word 67000 to our question vocabulary.
# Adding word 19000 to our answer vocabulary.
# Adding word 68000 to our question vocabulary.
# Adding word 69000 to our question vocabulary.
# Adding word 70000 to our question vocabulary.
# Adding word 71000 to our question vocabulary.
# Adding word 72000 to our question vocabulary.
# Adding word 20000 to our answer vocabulary.
# Adding word 73000 to our question vocabulary.
# Adding word 74000 to our question vocabulary.
# Adding word 75000 to our question vocabulary.
# Adding word 76000 to our question vocabulary.
# Adding word 77000 to our question vocabulary.
# Adding word 21000 to our answer vocabulary.
# Adding word 78000 to our question vocabulary.
# Adding word 79000 to our question vocabulary.
# Adding word 80000 to our question vocabulary.
# Adding word 81000 to our question vocabulary.
# Adding word 82000 to our question vocabulary.
# Adding word 22000 to our answer vocabulary.
# Adding word 83000 to our question vocabulary.
# Adding word 84000 to our question vocabulary.
# Adding word 85000 to our question vocabulary.
# Adding word 86000 to our question vocabulary.
# Adding word 87000 to our question vocabulary.
# Adding word 23000 to our answer vocabulary.
# Adding word 88000 to our question vocabulary.
# Adding word 89000 to our question vocabulary.
# Adding word 90000 to our question vocabulary.
# Adding word 24000 to our answer vocabulary.
# Adding word 91000 to our question vocabulary.
# Adding word 25000 to our answer vocabulary.
# Adding word 92000 to our question vocabulary.
# Adding word 26000 to our answer vocabulary.
# Adding word 93000 to our question vocabulary.
# Adding word 94000 to our question vocabulary.
# Adding word 95000 to our question vocabulary.
# Adding word 96000 to our question vocabulary.
# Adding word 97000 to our question vocabulary.
# Adding word 27000 to our answer vocabulary.
# Adding word 98000 to our question vocabulary.
# Adding word 99000 to our question vocabulary.
# Adding word 100000 to our question vocabulary.
# Adding word 101000 to our question vocabulary.
# Adding word 102000 to our question vocabulary.
# Adding word 28000 to our answer vocabulary.
# Adding word 103000 to our question vocabulary.
# Adding word 104000 to our question vocabulary.
# Adding word 105000 to our question vocabulary.
# Adding word 106000 to our question vocabulary.
# Adding word 29000 to our answer vocabulary.
# Adding word 107000 to our question vocabulary.
# Adding word 108000 to our question vocabulary.
# Adding word 109000 to our question vocabulary.
# Adding word 30000 to our answer vocabulary.
# Adding word 110000 to our question vocabulary.
# Adding word 111000 to our question vocabulary.
# Adding word 112000 to our question vocabulary.
# Adding word 113000 to our question vocabulary.
# Adding word 31000 to our answer vocabulary.
# Adding word 114000 to our question vocabulary.
# Adding word 115000 to our question vocabulary.
# Adding word 116000 to our question vocabulary.
# Adding word 32000 to our answer vocabulary.
# Adding word 117000 to our question vocabulary.
# Adding word 118000 to our question vocabulary.
# Adding word 119000 to our question vocabulary.
# Adding word 120000 to our question vocabulary.
# Adding word 121000 to our question vocabulary.
# Adding word 122000 to our question vocabulary.
# Adding word 33000 to our answer vocabulary.
# Adding word 123000 to our question vocabulary.
# Adding word 124000 to our question vocabulary.
# Adding word 125000 to our question vocabulary.
# Adding word 126000 to our question vocabulary.
# Adding word 34000 to our answer vocabulary.
# Adding word 127000 to our question vocabulary.
# Adding word 128000 to our question vocabulary.
# Adding word 129000 to our question vocabulary.
# Adding word 130000 to our question vocabulary.
# Adding word 131000 to our question vocabulary.
# Adding word 35000 to our answer vocabulary.
# Adding word 132000 to our question vocabulary.
# Adding word 133000 to our question vocabulary.
# Adding word 134000 to our question vocabulary.
# Adding word 135000 to our question vocabulary.
# Adding word 36000 to our answer vocabulary.
# Adding word 136000 to our question vocabulary.
# Adding word 137000 to our question vocabulary.
# Adding word 138000 to our question vocabulary.
# Adding word 139000 to our question vocabulary.
# Adding word 37000 to our answer vocabulary.
# Adding word 140000 to our question vocabulary.
# Adding word 141000 to our question vocabulary.
# Adding word 142000 to our question vocabulary.
# Adding word 143000 to our question vocabulary.
# Adding word 38000 to our answer vocabulary.
# Adding word 144000 to our question vocabulary.
# Adding word 145000 to our question vocabulary.
# Adding word 146000 to our question vocabulary.
# Adding word 147000 to our question vocabulary.
# Adding word 39000 to our answer vocabulary.
# Adding word 148000 to our question vocabulary.
# Adding word 149000 to our question vocabulary.
# Adding word 150000 to our question vocabulary.
# Adding word 151000 to our question vocabulary.
# Adding word 40000 to our answer vocabulary.
# Adding word 152000 to our question vocabulary.
# Adding word 153000 to our question vocabulary.
# Adding word 154000 to our question vocabulary.
# Adding word 41000 to our answer vocabulary.
# Adding word 155000 to our question vocabulary.
# Adding word 156000 to our question vocabulary.
# Adding word 157000 to our question vocabulary.
# Adding word 158000 to our question vocabulary.
# Adding word 42000 to our answer vocabulary.
# Adding word 159000 to our question vocabulary.
# Adding word 160000 to our question vocabulary.
# Adding word 161000 to our question vocabulary.
# Adding word 43000 to our answer vocabulary.
# Adding word 162000 to our question vocabulary.
# Adding word 163000 to our question vocabulary.
# Adding word 164000 to our question vocabulary.
# Adding word 165000 to our question vocabulary.
# Adding word 166000 to our question vocabulary.
# Adding word 44000 to our answer vocabulary.
# Adding word 167000 to our question vocabulary.
# Adding word 168000 to our question vocabulary.
# Adding word 169000 to our question vocabulary.
# Adding word 170000 to our question vocabulary.
# Adding word 171000 to our question vocabulary.
# Adding word 45000 to our answer vocabulary.
# Adding word 172000 to our question vocabulary.
# Adding word 173000 to our question vocabulary.
# Adding word 174000 to our question vocabulary.
# Adding word 175000 to our question vocabulary.
# Adding word 46000 to our answer vocabulary.
# Adding word 176000 to our question vocabulary.
# Adding word 177000 to our question vocabulary.
# Adding word 178000 to our question vocabulary.
# Adding word 47000 to our answer vocabulary.
# Adding word 179000 to our question vocabulary.
# Adding word 180000 to our question vocabulary.
# Adding word 181000 to our question vocabulary.
# Adding word 182000 to our question vocabulary.
# Adding word 183000 to our question vocabulary.
# Adding word 48000 to our answer vocabulary.
# Adding word 184000 to our question vocabulary.
# Adding word 185000 to our question vocabulary.
# Adding word 186000 to our question vocabulary.
# Adding word 187000 to our question vocabulary.
# Adding word 188000 to our question vocabulary.
# Adding word 49000 to our answer vocabulary.
# Adding word 189000 to our question vocabulary.
# Adding word 190000 to our question vocabulary.
# Adding word 191000 to our question vocabulary.
# Adding word 192000 to our question vocabulary.
# Adding word 50000 to our answer vocabulary.
# Adding word 193000 to our question vocabulary.
# Adding word 194000 to our question vocabulary.
# Adding word 195000 to our question vocabulary.
# Adding word 196000 to our question vocabulary.
# Adding word 51000 to our answer vocabulary.
# Adding word 197000 to our question vocabulary.
# Adding word 198000 to our question vocabulary.
# Adding word 199000 to our question vocabulary.
# Adding word 200000 to our question vocabulary.
# Adding word 201000 to our question vocabulary.
# Adding word 202000 to our question vocabulary.
# Adding word 52000 to our answer vocabulary.
# Adding word 203000 to our question vocabulary.
# Adding word 204000 to our question vocabulary.
# Adding word 205000 to our question vocabulary.
# Adding word 206000 to our question vocabulary.
# Adding word 207000 to our question vocabulary.
# Adding word 53000 to our answer vocabulary.
# Adding word 208000 to our question vocabulary.
# Adding word 209000 to our question vocabulary.
# Adding word 210000 to our question vocabulary.
# Adding word 211000 to our question vocabulary.
# Adding word 212000 to our question vocabulary.
# Adding word 54000 to our answer vocabulary.
# Adding word 213000 to our question vocabulary.
# Adding word 214000 to our question vocabulary.
# Adding word 215000 to our question vocabulary.
# Adding word 55000 to our answer vocabulary.
# Adding word 216000 to our question vocabulary.
# Adding word 217000 to our question vocabulary.
# Adding word 218000 to our question vocabulary.
# Adding word 56000 to our answer vocabulary.
# Adding word 219000 to our question vocabulary.
# Adding word 220000 to our question vocabulary.
# Adding word 57000 to our answer vocabulary.
# Adding word 221000 to our question vocabulary.
# Adding word 222000 to our question vocabulary.
# Adding word 223000 to our question vocabulary.
# Adding word 58000 to our answer vocabulary.
# Adding word 224000 to our question vocabulary.
# Adding word 225000 to our question vocabulary.
# Adding word 226000 to our question vocabulary.
# Adding word 227000 to our question vocabulary.
# Adding word 59000 to our answer vocabulary.
# Adding word 228000 to our question vocabulary.
# Adding word 229000 to our question vocabulary.
# Adding word 230000 to our question vocabulary.
# Adding word 60000 to our answer vocabulary.
# Adding word 231000 to our question vocabulary.
# Adding word 232000 to our question vocabulary.
# Adding word 233000 to our question vocabulary.
# Adding word 234000 to our question vocabulary.
# Adding word 61000 to our answer vocabulary.
# Adding word 235000 to our question vocabulary.
# Adding word 236000 to our question vocabulary.
# Adding word 237000 to our question vocabulary.
# Adding word 238000 to our question vocabulary.
# Adding word 62000 to our answer vocabulary.
# Adding word 239000 to our question vocabulary.
# Adding word 240000 to our question vocabulary.
# Adding word 241000 to our question vocabulary.
# Adding word 242000 to our question vocabulary.
# Adding word 243000 to our question vocabulary.
# Adding word 244000 to our question vocabulary.
# Adding word 245000 to our question vocabulary.
# Adding word 63000 to our answer vocabulary.
# Adding word 246000 to our question vocabulary.
# Adding word 247000 to our question vocabulary.
# Adding word 248000 to our question vocabulary.
# Adding word 249000 to our question vocabulary.
# Adding word 250000 to our question vocabulary.
# Adding word 64000 to our answer vocabulary.
# Adding word 251000 to our question vocabulary.
# Adding word 252000 to our question vocabulary.
# Adding word 65000 to our answer vocabulary.
# Adding word 253000 to our question vocabulary.
# Adding word 254000 to our question vocabulary.
# Adding word 255000 to our question vocabulary.
# Adding word 256000 to our question vocabulary.
# Adding word 66000 to our answer vocabulary.
# Adding word 257000 to our question vocabulary.
# Adding word 258000 to our question vocabulary.
# Adding word 259000 to our question vocabulary.
# Adding word 260000 to our question vocabulary.
# Adding word 67000 to our answer vocabulary.
# Adding word 261000 to our question vocabulary.
# Adding word 262000 to our question vocabulary.
# Adding word 263000 to our question vocabulary.
# Adding word 68000 to our answer vocabulary.
# Adding word 264000 to our question vocabulary.
# Adding word 265000 to our question vocabulary.
# Adding word 266000 to our question vocabulary.
# Adding word 69000 to our answer vocabulary.
# Adding word 267000 to our question vocabulary.
# Adding word 268000 to our question vocabulary.
# Adding word 269000 to our question vocabulary.
# Adding word 270000 to our question vocabulary.
# Adding word 70000 to our answer vocabulary.
# Adding word 271000 to our question vocabulary.
# Adding word 272000 to our question vocabulary.
# Adding word 273000 to our question vocabulary.
# Adding word 274000 to our question vocabulary.
# Adding word 275000 to our question vocabulary.
# Adding word 71000 to our answer vocabulary.
# Adding word 276000 to our question vocabulary.
# Adding word 277000 to our question vocabulary.
# Adding word 278000 to our question vocabulary.
# Adding word 279000 to our question vocabulary.
# Adding word 72000 to our answer vocabulary.
# Adding word 280000 to our question vocabulary.
# Adding word 281000 to our question vocabulary.
# Adding word 282000 to our question vocabulary.
# Adding word 73000 to our answer vocabulary.
# Adding word 283000 to our question vocabulary.
# Adding word 284000 to our question vocabulary.
# Adding word 285000 to our question vocabulary.
# Adding word 286000 to our question vocabulary.
# Adding word 74000 to our answer vocabulary.
# Adding word 287000 to our question vocabulary.
# Adding word 288000 to our question vocabulary.
# Adding word 289000 to our question vocabulary.
# Adding word 290000 to our question vocabulary.
# Adding word 75000 to our answer vocabulary.
# Adding word 291000 to our question vocabulary.
# Adding word 292000 to our question vocabulary.
# Adding word 293000 to our question vocabulary.
# Adding word 76000 to our answer vocabulary.
# Adding word 294000 to our question vocabulary.
# Adding word 295000 to our question vocabulary.
# Adding word 296000 to our question vocabulary.
# Adding word 297000 to our question vocabulary.
# Adding word 77000 to our answer vocabulary.
# Adding word 298000 to our question vocabulary.
# Adding word 299000 to our question vocabulary.
# Adding word 300000 to our question vocabulary.
# Adding word 301000 to our question vocabulary.
# Adding word 302000 to our question vocabulary.
# Adding word 78000 to our answer vocabulary.
# Adding word 303000 to our question vocabulary.
# Adding word 304000 to our question vocabulary.
# Adding word 305000 to our question vocabulary.
# Adding word 306000 to our question vocabulary.
# Adding word 79000 to our answer vocabulary.
# Adding word 307000 to our question vocabulary.
# Adding word 308000 to our question vocabulary.
# Adding word 309000 to our question vocabulary.
# Adding word 80000 to our answer vocabulary.
# Adding word 310000 to our question vocabulary.
# Adding word 311000 to our question vocabulary.
# Adding word 312000 to our question vocabulary.
# Adding word 313000 to our question vocabulary.
# Adding word 81000 to our answer vocabulary.
# Adding word 314000 to our question vocabulary.
# Adding word 315000 to our question vocabulary.
# Adding word 316000 to our question vocabulary.
# Adding word 82000 to our answer vocabulary.
# Adding word 317000 to our question vocabulary.
# Adding word 83000 to our answer vocabulary.
# Adding word 318000 to our question vocabulary.
# Adding word 319000 to our question vocabulary.
# Adding word 320000 to our question vocabulary.
# Adding word 84000 to our answer vocabulary.
# Adding word 321000 to our question vocabulary.
# Adding word 322000 to our question vocabulary.
# Adding word 323000 to our question vocabulary.
# Adding word 324000 to our question vocabulary.
# Adding word 85000 to our answer vocabulary.
# Adding word 325000 to our question vocabulary.
# Adding word 326000 to our question vocabulary.
# Adding word 327000 to our question vocabulary.
# Adding word 328000 to our question vocabulary.
# Adding word 86000 to our answer vocabulary.
# Adding word 329000 to our question vocabulary.
# Adding word 330000 to our question vocabulary.
# Adding word 331000 to our question vocabulary.
# Adding word 332000 to our question vocabulary.
# Adding word 87000 to our answer vocabulary.
# Adding word 333000 to our question vocabulary.
# Adding word 334000 to our question vocabulary.
# Adding word 335000 to our question vocabulary.
# Adding word 88000 to our answer vocabulary.
# Adding word 336000 to our question vocabulary.
# Adding word 337000 to our question vocabulary.
# Adding word 338000 to our question vocabulary.
# Adding word 339000 to our question vocabulary.
# Adding word 89000 to our answer vocabulary.
# Adding word 340000 to our question vocabulary.
# Adding word 341000 to our question vocabulary.
# Adding word 342000 to our question vocabulary.
# Adding word 90000 to our answer vocabulary.
# Adding word 343000 to our question vocabulary.
# Adding word 344000 to our question vocabulary.
# Adding word 345000 to our question vocabulary.
# Adding word 346000 to our question vocabulary.
# Adding word 91000 to our answer vocabulary.
# Adding word 347000 to our question vocabulary.
# Adding word 348000 to our question vocabulary.
# Adding word 349000 to our question vocabulary.
# Adding word 350000 to our question vocabulary.
# Adding word 92000 to our answer vocabulary.
# Adding word 351000 to our question vocabulary.
# Adding word 352000 to our question vocabulary.
# Adding word 353000 to our question vocabulary.
# Adding word 354000 to our question vocabulary.
# Adding word 93000 to our answer vocabulary.
# Adding word 355000 to our question vocabulary.
# Adding word 356000 to our question vocabulary.
# Adding word 357000 to our question vocabulary.
# Adding word 358000 to our question vocabulary.
# Adding word 94000 to our answer vocabulary.
# Adding word 359000 to our question vocabulary.
# Adding word 360000 to our question vocabulary.
# Adding word 361000 to our question vocabulary.
# Adding word 95000 to our answer vocabulary.
# Adding word 362000 to our question vocabulary.
# Adding word 96000 to our answer vocabulary.
# Adding word 363000 to our question vocabulary.
# Adding word 97000 to our answer vocabulary.
# Adding word 364000 to our question vocabulary.
# Adding word 365000 to our question vocabulary.
# Adding word 366000 to our question vocabulary.
# Adding word 367000 to our question vocabulary.
# Adding word 98000 to our answer vocabulary.
# Adding word 368000 to our question vocabulary.
# Adding word 369000 to our question vocabulary.
# Adding word 370000 to our question vocabulary.
# Adding word 371000 to our question vocabulary.
# Adding word 99000 to our answer vocabulary.
# Adding word 372000 to our question vocabulary.
# Adding word 373000 to our question vocabulary.
# Adding word 374000 to our question vocabulary.
# Adding word 100000 to our answer vocabulary.
# Adding word 375000 to our question vocabulary.
# Adding word 376000 to our question vocabulary.
# Adding word 377000 to our question vocabulary.
# Adding word 378000 to our question vocabulary.
# Adding word 101000 to our answer vocabulary.
# Adding word 379000 to our question vocabulary.
# Adding word 102000 to our answer vocabulary.
# Adding word 380000 to our question vocabulary.
# Adding word 381000 to our question vocabulary.
# Adding word 103000 to our answer vocabulary.
# Adding word 382000 to our question vocabulary.
# Adding word 383000 to our question vocabulary.
# Adding word 104000 to our answer vocabulary.
# Adding word 384000 to our question vocabulary.
# Adding word 385000 to our question vocabulary.
# Adding word 386000 to our question vocabulary.
# Adding word 387000 to our question vocabulary.
# Adding word 105000 to our answer vocabulary.
# Adding word 388000 to our question vocabulary.
# Adding word 389000 to our question vocabulary.
# Adding word 390000 to our question vocabulary.
# Adding word 106000 to our answer vocabulary.
# Adding word 391000 to our question vocabulary.
# Adding word 392000 to our question vocabulary.
# Adding word 393000 to our question vocabulary.
# Adding word 107000 to our answer vocabulary.
# Adding word 394000 to our question vocabulary.
# Adding word 395000 to our question vocabulary.
# Adding word 396000 to our question vocabulary.
# Adding word 108000 to our answer vocabulary.
# Adding word 397000 to our question vocabulary.
# Adding word 398000 to our question vocabulary.
# Adding word 399000 to our question vocabulary.
# Adding word 109000 to our answer vocabulary.
# Adding word 400000 to our question vocabulary.
# Adding word 401000 to our question vocabulary.
# Adding word 402000 to our question vocabulary.
# Adding word 403000 to our question vocabulary.
# Adding word 110000 to our answer vocabulary.
# Adding word 404000 to our question vocabulary.
# Adding word 405000 to our question vocabulary.
# Adding word 406000 to our question vocabulary.
# Adding word 407000 to our question vocabulary.
# Adding word 408000 to our question vocabulary.
# Adding word 409000 to our question vocabulary.
# Adding word 111000 to our answer vocabulary.
# Adding word 112000 to our answer vocabulary.
# Adding word 410000 to our question vocabulary.
# Adding word 411000 to our question vocabulary.
# Adding word 412000 to our question vocabulary.
# Adding word 113000 to our answer vocabulary.
# Adding word 413000 to our question vocabulary.
# Adding word 414000 to our question vocabulary.
# Adding word 415000 to our question vocabulary.
# Adding word 416000 to our question vocabulary.
# Adding word 114000 to our answer vocabulary.
# Adding word 115000 to our answer vocabulary.
# Adding word 417000 to our question vocabulary.
# Adding word 418000 to our question vocabulary.
# Adding word 116000 to our answer vocabulary.
# Adding word 419000 to our question vocabulary.
# Adding word 420000 to our question vocabulary.
# Adding word 421000 to our question vocabulary.
# Adding word 422000 to our question vocabulary.
# Adding word 423000 to our question vocabulary.
# Adding word 424000 to our question vocabulary.
# Adding word 117000 to our answer vocabulary.
# Adding word 425000 to our question vocabulary.
# Adding word 426000 to our question vocabulary.
# Adding word 118000 to our answer vocabulary.
# Adding word 427000 to our question vocabulary.
# Adding word 428000 to our question vocabulary.
# Adding word 429000 to our question vocabulary.
# Adding word 430000 to our question vocabulary.
# Adding word 119000 to our answer vocabulary.
# Adding word 431000 to our question vocabulary.
# Adding word 432000 to our question vocabulary.
# Adding word 433000 to our question vocabulary.
# Adding word 434000 to our question vocabulary.
# Adding word 120000 to our answer vocabulary.
# Adding word 435000 to our question vocabulary.
# Adding word 436000 to our question vocabulary.
# Adding word 437000 to our question vocabulary.
# Adding word 121000 to our answer vocabulary.
# Adding word 438000 to our question vocabulary.
# Adding word 439000 to our question vocabulary.
# Adding word 440000 to our question vocabulary.
# Adding word 122000 to our answer vocabulary.
# Adding word 441000 to our question vocabulary.
# Adding word 442000 to our question vocabulary.
# Adding word 443000 to our question vocabulary.
# Adding word 444000 to our question vocabulary.
# Adding word 123000 to our answer vocabulary.
# Adding word 445000 to our question vocabulary.
# Adding word 446000 to our question vocabulary.
# Adding word 447000 to our question vocabulary.
# Adding word 124000 to our answer vocabulary.
# Adding word 448000 to our question vocabulary.
# Adding word 125000 to our answer vocabulary.
# Adding word 449000 to our question vocabulary.
# Adding word 450000 to our question vocabulary.
# Adding word 126000 to our answer vocabulary.
# Adding word 451000 to our question vocabulary.
# Adding word 452000 to our question vocabulary.
# Adding word 127000 to our answer vocabulary.
# Adding word 453000 to our question vocabulary.
# Adding word 454000 to our question vocabulary.
# Adding word 455000 to our question vocabulary.
# Adding word 456000 to our question vocabulary.
# Adding word 128000 to our answer vocabulary.
# Adding word 457000 to our question vocabulary.
# Adding word 458000 to our question vocabulary.
# Adding word 459000 to our question vocabulary.
# Adding word 460000 to our question vocabulary.
# Adding word 461000 to our question vocabulary.
# Adding word 129000 to our answer vocabulary.
# Adding word 462000 to our question vocabulary.
# Adding word 463000 to our question vocabulary.
# Adding word 464000 to our question vocabulary.
# Adding word 465000 to our question vocabulary.
# Adding word 466000 to our question vocabulary.
# Adding word 130000 to our answer vocabulary.
# Adding word 467000 to our question vocabulary.
# Adding word 468000 to our question vocabulary.
# Adding word 469000 to our question vocabulary.
# Adding word 131000 to our answer vocabulary.
# Adding word 470000 to our question vocabulary.
# Adding word 132000 to our answer vocabulary.
# Adding word 471000 to our question vocabulary.
# Adding word 133000 to our answer vocabulary.
# Adding word 472000 to our question vocabulary.
# Adding word 473000 to our question vocabulary.
# Adding word 474000 to our question vocabulary.
# Adding word 475000 to our question vocabulary.
# Adding word 134000 to our answer vocabulary.
# Adding word 476000 to our question vocabulary.
# Adding word 477000 to our question vocabulary.
# Adding word 135000 to our answer vocabulary.
# Adding word 478000 to our question vocabulary.
# Adding word 479000 to our question vocabulary.
# Adding word 480000 to our question vocabulary.
# Adding word 136000 to our answer vocabulary.
# Adding word 481000 to our question vocabulary.
# Adding word 482000 to our question vocabulary.
# Adding word 483000 to our question vocabulary.
# Adding word 484000 to our question vocabulary.
# Adding word 137000 to our answer vocabulary.
# Adding word 485000 to our question vocabulary.
# Adding word 486000 to our question vocabulary.
# Adding word 487000 to our question vocabulary.
# Adding word 488000 to our question vocabulary.
# Adding word 138000 to our answer vocabulary.
# Adding word 489000 to our question vocabulary.
# Adding word 490000 to our question vocabulary.
# Adding word 491000 to our question vocabulary.
# Adding word 139000 to our answer vocabulary.
# Adding word 492000 to our question vocabulary.
# Adding word 493000 to our question vocabulary.
# Adding word 494000 to our question vocabulary.
# Adding word 140000 to our answer vocabulary.
# Adding word 495000 to our question vocabulary.
# Adding word 141000 to our answer vocabulary.
# Adding word 496000 to our question vocabulary.
# Adding word 142000 to our answer vocabulary.
# Adding word 497000 to our question vocabulary.
# Adding word 143000 to our answer vocabulary.
# Adding word 498000 to our question vocabulary.
# Adding word 499000 to our question vocabulary.
# Adding word 500000 to our question vocabulary.
# Adding word 144000 to our answer vocabulary.
# Adding word 501000 to our question vocabulary.
# Adding word 502000 to our question vocabulary.
# Adding word 503000 to our question vocabulary.
# Adding word 145000 to our answer vocabulary.
# Adding word 504000 to our question vocabulary.
# Adding word 505000 to our question vocabulary.
# Adding word 506000 to our question vocabulary.
# Adding word 146000 to our answer vocabulary.
# Adding word 507000 to our question vocabulary.
# Adding word 508000 to our question vocabulary.
# Adding word 147000 to our answer vocabulary.
# Adding word 509000 to our question vocabulary.
# Adding word 148000 to our answer vocabulary.
# Adding word 510000 to our question vocabulary.
# Adding word 149000 to our answer vocabulary.
# Adding word 511000 to our question vocabulary.
# Adding word 512000 to our question vocabulary.
# Adding word 150000 to our answer vocabulary.
# Adding word 513000 to our question vocabulary.
# Adding word 514000 to our question vocabulary.
# Adding word 515000 to our question vocabulary.
# Adding word 516000 to our question vocabulary.
# Adding word 517000 to our question vocabulary.
# Adding word 151000 to our answer vocabulary.
# Adding word 518000 to our question vocabulary.
# Adding word 519000 to our question vocabulary.
# Adding word 520000 to our question vocabulary.
# Adding word 152000 to our answer vocabulary.
# Adding word 521000 to our question vocabulary.
# Adding word 522000 to our question vocabulary.
# Adding word 523000 to our question vocabulary.
# Adding word 153000 to our answer vocabulary.
# Adding word 524000 to our question vocabulary.
# Adding word 525000 to our question vocabulary.
# Adding word 526000 to our question vocabulary.
# Adding word 527000 to our question vocabulary.
# Adding word 528000 to our question vocabulary.
# Adding word 529000 to our question vocabulary.
# Adding word 154000 to our answer vocabulary.
# Adding word 530000 to our question vocabulary.
# Adding word 531000 to our question vocabulary.
# Adding word 532000 to our question vocabulary.
# Adding word 155000 to our answer vocabulary.
# Adding word 533000 to our question vocabulary.
# Adding word 534000 to our question vocabulary.
# Adding word 535000 to our question vocabulary.
# Adding word 536000 to our question vocabulary.
# Adding word 156000 to our answer vocabulary.
# Adding word 537000 to our question vocabulary.
# Adding word 157000 to our answer vocabulary.
# Adding word 538000 to our question vocabulary.
# Adding word 539000 to our question vocabulary.
# Adding word 540000 to our question vocabulary.
# Adding word 541000 to our question vocabulary.
# Adding word 542000 to our question vocabulary.
# Adding word 158000 to our answer vocabulary.
# Adding word 543000 to our question vocabulary.
# Adding word 544000 to our question vocabulary.
# Adding word 545000 to our question vocabulary.
# Adding word 159000 to our answer vocabulary.
# Adding word 546000 to our question vocabulary.
# Adding word 547000 to our question vocabulary.
# Adding word 548000 to our question vocabulary.
# Adding word 549000 to our question vocabulary.
# Adding word 160000 to our answer vocabulary.
# Adding word 550000 to our question vocabulary.
# Adding word 551000 to our question vocabulary.
# Adding word 161000 to our answer vocabulary.
# Adding word 552000 to our question vocabulary.
# Adding word 553000 to our question vocabulary.
# Adding word 162000 to our answer vocabulary.
# Adding word 163000 to our answer vocabulary.
# Adding word 554000 to our question vocabulary.
# Adding word 555000 to our question vocabulary.
# Adding word 164000 to our answer vocabulary.
# Adding word 556000 to our question vocabulary.
# Adding word 557000 to our question vocabulary.
# Adding word 165000 to our answer vocabulary.
# Adding word 558000 to our question vocabulary.
# Adding word 559000 to our question vocabulary.
# Adding word 560000 to our question vocabulary.
# Adding word 166000 to our answer vocabulary.
# Adding word 561000 to our question vocabulary.
# Adding word 562000 to our question vocabulary.
# Adding word 167000 to our answer vocabulary.
# Adding word 563000 to our question vocabulary.
# Adding word 564000 to our question vocabulary.
# Adding word 565000 to our question vocabulary.
# Adding word 168000 to our answer vocabulary.
# Adding word 566000 to our question vocabulary.
# Adding word 567000 to our question vocabulary.
# Adding word 169000 to our answer vocabulary.
# Adding word 568000 to our question vocabulary.
# Adding word 569000 to our question vocabulary.
# Adding word 570000 to our question vocabulary.
# Adding word 571000 to our question vocabulary.
# Adding word 170000 to our answer vocabulary.
# Adding word 572000 to our question vocabulary.
# Adding word 573000 to our question vocabulary.
# Adding word 574000 to our question vocabulary.
# Adding word 171000 to our answer vocabulary.
# Adding word 575000 to our question vocabulary.
# Adding word 172000 to our answer vocabulary.
# Adding word 576000 to our question vocabulary.
# Adding word 173000 to our answer vocabulary.
# Adding word 577000 to our question vocabulary.
# Adding word 578000 to our question vocabulary.
# Adding word 579000 to our question vocabulary.
# Adding word 174000 to our answer vocabulary.
# Adding word 580000 to our question vocabulary.
# Adding word 581000 to our question vocabulary.
# Adding word 582000 to our question vocabulary.
# Adding word 583000 to our question vocabulary.
# Adding word 175000 to our answer vocabulary.
# Adding word 584000 to our question vocabulary.
# Adding word 585000 to our question vocabulary.
# Adding word 176000 to our answer vocabulary.
# Adding word 586000 to our question vocabulary.
# Adding word 587000 to our question vocabulary.
# Adding word 177000 to our answer vocabulary.
# Adding word 588000 to our question vocabulary.
# Adding word 589000 to our question vocabulary.
# Adding word 590000 to our question vocabulary.
# Adding word 178000 to our answer vocabulary.
# Adding word 591000 to our question vocabulary.
# Adding word 592000 to our question vocabulary.
# Adding word 593000 to our question vocabulary.
# Adding word 179000 to our answer vocabulary.
# Adding word 594000 to our question vocabulary.
# Adding word 595000 to our question vocabulary.
# Adding word 180000 to our answer vocabulary.
# Adding word 596000 to our question vocabulary.
# Adding word 597000 to our question vocabulary.
# Adding word 181000 to our answer vocabulary.
# Adding word 598000 to our question vocabulary.
# Adding word 599000 to our question vocabulary.
# Adding word 182000 to our answer vocabulary.
# Adding word 600000 to our question vocabulary.
# Adding word 601000 to our question vocabulary.
# Adding word 602000 to our question vocabulary.
# Adding word 183000 to our answer vocabulary.
# Adding word 603000 to our question vocabulary.
# Adding word 604000 to our question vocabulary.
# Adding word 605000 to our question vocabulary.
# Adding word 184000 to our answer vocabulary.
# Adding word 606000 to our question vocabulary.
# Adding word 607000 to our question vocabulary.
# Adding word 608000 to our question vocabulary.
# Adding word 185000 to our answer vocabulary.
# Adding word 609000 to our question vocabulary.
# Adding word 186000 to our answer vocabulary.
# Adding word 610000 to our question vocabulary.
# Adding word 187000 to our answer vocabulary.
# Adding word 611000 to our question vocabulary.
# Adding word 612000 to our question vocabulary.
# Adding word 613000 to our question vocabulary.
# Adding word 188000 to our answer vocabulary.
# Adding word 614000 to our question vocabulary.
# Adding word 615000 to our question vocabulary.
# Adding word 189000 to our answer vocabulary.
# Adding word 616000 to our question vocabulary.
# Adding word 617000 to our question vocabulary.
# Adding word 190000 to our answer vocabulary.
# Adding word 618000 to our question vocabulary.
# Adding word 619000 to our question vocabulary.
# Adding word 620000 to our question vocabulary.
# Adding word 621000 to our question vocabulary.
# Adding word 191000 to our answer vocabulary.
# Adding word 622000 to our question vocabulary.
# Adding word 623000 to our question vocabulary.
# Adding word 624000 to our question vocabulary.
# Adding word 625000 to our question vocabulary.
# Adding word 192000 to our answer vocabulary.
# Adding word 626000 to our question vocabulary.
# Adding word 627000 to our question vocabulary.
# Adding word 628000 to our question vocabulary.
# Adding word 193000 to our answer vocabulary.
# Adding word 629000 to our question vocabulary.
# Adding word 630000 to our question vocabulary.
# Adding word 631000 to our question vocabulary.
# Adding word 632000 to our question vocabulary.
# Adding word 194000 to our answer vocabulary.
# Adding word 633000 to our question vocabulary.
# Adding word 634000 to our question vocabulary.
# Adding word 635000 to our question vocabulary.
# Adding word 636000 to our question vocabulary.
# Adding word 195000 to our answer vocabulary.
# Adding word 637000 to our question vocabulary.
# Adding word 638000 to our question vocabulary.
# Adding word 639000 to our question vocabulary.
# Adding word 196000 to our answer vocabulary.
# Adding word 640000 to our question vocabulary.
# Adding word 641000 to our question vocabulary.
# Adding word 642000 to our question vocabulary.
# Adding word 197000 to our answer vocabulary.
# Adding word 643000 to our question vocabulary.
# Adding word 644000 to our question vocabulary.
# Adding word 645000 to our question vocabulary.
# Adding word 646000 to our question vocabulary.
# Adding word 198000 to our answer vocabulary.
# Adding word 647000 to our question vocabulary.
# Adding word 648000 to our question vocabulary.
# Adding word 649000 to our question vocabulary.
# Adding word 199000 to our answer vocabulary.
# Adding word 650000 to our question vocabulary.
# Adding word 200000 to our answer vocabulary.
# Adding word 651000 to our question vocabulary.
# Adding word 652000 to our question vocabulary.
# Adding word 201000 to our answer vocabulary.
# Adding word 653000 to our question vocabulary.
# Adding word 654000 to our question vocabulary.
# Adding word 655000 to our question vocabulary.
# Adding word 202000 to our answer vocabulary.
# Adding word 656000 to our question vocabulary.
# Adding word 657000 to our question vocabulary.
# Adding word 203000 to our answer vocabulary.
# Adding word 658000 to our question vocabulary.
# Adding word 659000 to our question vocabulary.
# Adding word 660000 to our question vocabulary.
# Adding word 661000 to our question vocabulary.
# Adding word 204000 to our answer vocabulary.
# Adding word 662000 to our question vocabulary.
# Adding word 663000 to our question vocabulary.
# Adding word 664000 to our question vocabulary.
# Adding word 205000 to our answer vocabulary.
# Adding word 665000 to our question vocabulary.
# Adding word 666000 to our question vocabulary.
# Adding word 667000 to our question vocabulary.
# Adding word 206000 to our answer vocabulary.
# Adding word 668000 to our question vocabulary.
# Adding word 669000 to our question vocabulary.
# Adding word 670000 to our question vocabulary.
# Adding word 671000 to our question vocabulary.
# Adding word 672000 to our question vocabulary.
# Adding word 207000 to our answer vocabulary.
# Adding word 673000 to our question vocabulary.
# Adding word 674000 to our question vocabulary.
# Adding word 675000 to our question vocabulary.
# Adding word 676000 to our question vocabulary.
# Adding word 208000 to our answer vocabulary.
# Adding word 677000 to our question vocabulary.
# Adding word 678000 to our question vocabulary.
# Adding word 679000 to our question vocabulary.
# Adding word 209000 to our answer vocabulary.
# Adding word 680000 to our question vocabulary.
# Adding word 681000 to our question vocabulary.
# Adding word 682000 to our question vocabulary.
# Adding word 210000 to our answer vocabulary.
# Adding word 683000 to our question vocabulary.
# Adding word 684000 to our question vocabulary.
# Adding word 211000 to our answer vocabulary.
# Adding word 685000 to our question vocabulary.
# Adding word 686000 to our question vocabulary.
# Adding word 687000 to our question vocabulary.
# Adding word 212000 to our answer vocabulary.
# Adding word 688000 to our question vocabulary.
# Adding word 689000 to our question vocabulary.
# Adding word 213000 to our answer vocabulary.
# Adding word 690000 to our question vocabulary.
# Adding word 691000 to our question vocabulary.
# Adding word 692000 to our question vocabulary.
# Adding word 214000 to our answer vocabulary.
# Adding word 693000 to our question vocabulary.
# Adding word 694000 to our question vocabulary.
# Adding word 695000 to our question vocabulary.
# Adding word 215000 to our answer vocabulary.
# Adding word 696000 to our question vocabulary.
# Adding word 697000 to our question vocabulary.
# Adding word 698000 to our question vocabulary.
# Adding word 216000 to our answer vocabulary.
# Adding word 699000 to our question vocabulary.
# Adding word 700000 to our question vocabulary.
# Adding word 701000 to our question vocabulary.
# Adding word 702000 to our question vocabulary.
# Adding word 217000 to our answer vocabulary.
# Adding word 703000 to our question vocabulary.
# Adding word 704000 to our question vocabulary.
# Adding word 218000 to our answer vocabulary.
# Adding word 705000 to our question vocabulary.
# Adding word 706000 to our question vocabulary.
# Adding word 707000 to our question vocabulary.
# Adding word 219000 to our answer vocabulary.
# Adding word 708000 to our question vocabulary.
# Adding word 709000 to our question vocabulary.
# Adding word 220000 to our answer vocabulary.
# Adding word 710000 to our question vocabulary.
# Adding word 711000 to our question vocabulary.
# Adding word 221000 to our answer vocabulary.
# Adding word 712000 to our question vocabulary.
# Adding word 713000 to our question vocabulary.
# Adding word 714000 to our question vocabulary.
# Adding word 222000 to our answer vocabulary.
# Adding word 715000 to our question vocabulary.
# Adding word 716000 to our question vocabulary.
# Adding word 717000 to our question vocabulary.
# Adding word 718000 to our question vocabulary.
# Adding word 223000 to our answer vocabulary.
# Adding word 719000 to our question vocabulary.
# Adding word 720000 to our question vocabulary.
# Adding word 721000 to our question vocabulary.
# Adding word 224000 to our answer vocabulary.
# Adding word 722000 to our question vocabulary.
# Adding word 225000 to our answer vocabulary.
# Adding word 723000 to our question vocabulary.
# Adding word 226000 to our answer vocabulary.
# Adding word 724000 to our question vocabulary.
# Adding word 725000 to our question vocabulary.
# Adding word 227000 to our answer vocabulary.
# Adding word 726000 to our question vocabulary.
# Adding word 228000 to our answer vocabulary.
# Adding word 727000 to our question vocabulary.
# Adding word 728000 to our question vocabulary.
# Adding word 229000 to our answer vocabulary.
# Adding word 729000 to our question vocabulary.
# Adding word 730000 to our question vocabulary.
# Adding word 731000 to our question vocabulary.
# Adding word 732000 to our question vocabulary.
# Adding word 230000 to our answer vocabulary.
# Adding word 733000 to our question vocabulary.
# Adding word 734000 to our question vocabulary.
# Adding word 735000 to our question vocabulary.
# Adding word 231000 to our answer vocabulary.
# Adding word 736000 to our question vocabulary.
# Adding word 232000 to our answer vocabulary.
# Adding word 737000 to our question vocabulary.
# Adding word 233000 to our answer vocabulary.
# Adding word 738000 to our question vocabulary.
# Adding word 739000 to our question vocabulary.
# Adding word 740000 to our question vocabulary.
# Adding word 234000 to our answer vocabulary.
# Adding word 741000 to our question vocabulary.
# Adding word 235000 to our answer vocabulary.
# Adding word 742000 to our question vocabulary.
# Adding word 743000 to our question vocabulary.
# Adding word 236000 to our answer vocabulary.
# Adding word 744000 to our question vocabulary.
# Adding word 745000 to our question vocabulary.
# Adding word 746000 to our question vocabulary.
# Adding word 237000 to our answer vocabulary.
# Adding word 747000 to our question vocabulary.
# Adding word 748000 to our question vocabulary.
# Adding word 749000 to our question vocabulary.
# Adding word 238000 to our answer vocabulary.
# Adding word 750000 to our question vocabulary.
# Adding word 751000 to our question vocabulary.
# Adding word 239000 to our answer vocabulary.
# Adding word 752000 to our question vocabulary.
# Adding word 753000 to our question vocabulary.
# Adding word 240000 to our answer vocabulary.
# Adding word 754000 to our question vocabulary.
# Adding word 755000 to our question vocabulary.
# Adding word 756000 to our question vocabulary.
# Adding word 757000 to our question vocabulary.
# Adding word 241000 to our answer vocabulary.
# Adding word 758000 to our question vocabulary.
# Adding word 242000 to our answer vocabulary.
# Adding word 759000 to our question vocabulary.
# Adding word 243000 to our answer vocabulary.
# Adding word 760000 to our question vocabulary.
# Adding word 761000 to our question vocabulary.
# Adding word 762000 to our question vocabulary.
# Adding word 763000 to our question vocabulary.
# Adding word 244000 to our answer vocabulary.
# Adding word 764000 to our question vocabulary.
# Adding word 765000 to our question vocabulary.
# Adding word 766000 to our question vocabulary.
# Adding word 245000 to our answer vocabulary.
# Adding word 767000 to our question vocabulary.
# Adding word 246000 to our answer vocabulary.
# Adding word 768000 to our question vocabulary.
# Adding word 769000 to our question vocabulary.
# Adding word 247000 to our answer vocabulary.
# Adding word 770000 to our question vocabulary.
# Adding word 771000 to our question vocabulary.
# Adding word 248000 to our answer vocabulary.
# Adding word 772000 to our question vocabulary.
# Adding word 773000 to our question vocabulary.
# Adding word 774000 to our question vocabulary.
# Adding word 775000 to our question vocabulary.
# Adding word 249000 to our answer vocabulary.
# Adding word 776000 to our question vocabulary.
# Adding word 777000 to our question vocabulary.
# Adding word 778000 to our question vocabulary.
# Adding word 779000 to our question vocabulary.
# Adding word 250000 to our answer vocabulary.
# Adding word 780000 to our question vocabulary.
# Adding word 781000 to our question vocabulary.
# Adding word 782000 to our question vocabulary.
# Adding word 251000 to our answer vocabulary.
# Adding word 783000 to our question vocabulary.
# Adding word 784000 to our question vocabulary.
# Adding word 785000 to our question vocabulary.
# Adding word 252000 to our answer vocabulary.
# Adding word 786000 to our question vocabulary.
# Adding word 787000 to our question vocabulary.
# Adding word 253000 to our answer vocabulary.
# Adding word 788000 to our question vocabulary.
# Adding word 789000 to our question vocabulary.
# Adding word 790000 to our question vocabulary.
# Adding word 254000 to our answer vocabulary.
# Adding word 791000 to our question vocabulary.
# Adding word 792000 to our question vocabulary.
# Adding word 793000 to our question vocabulary.
# Adding word 255000 to our answer vocabulary.
# Adding word 794000 to our question vocabulary.
# Adding word 795000 to our question vocabulary.
# Adding word 256000 to our answer vocabulary.
# Adding word 796000 to our question vocabulary.
# Adding word 257000 to our answer vocabulary.
# Adding word 797000 to our question vocabulary.
# Adding word 798000 to our question vocabulary.
# Adding word 258000 to our answer vocabulary.
# Adding word 799000 to our question vocabulary.
# Adding word 800000 to our question vocabulary.
# Adding word 801000 to our question vocabulary.
# Adding word 802000 to our question vocabulary.
# Adding word 259000 to our answer vocabulary.
# Adding word 803000 to our question vocabulary.
# Adding word 804000 to our question vocabulary.
# Adding word 805000 to our question vocabulary.
# Adding word 806000 to our question vocabulary.
# Adding word 260000 to our answer vocabulary.
# Adding word 807000 to our question vocabulary.
# Adding word 808000 to our question vocabulary.
# Adding word 809000 to our question vocabulary.
# Adding word 810000 to our question vocabulary.
# Adding word 261000 to our answer vocabulary.
# Adding word 811000 to our question vocabulary.
# Adding word 812000 to our question vocabulary.
# Adding word 813000 to our question vocabulary.
# Adding word 262000 to our answer vocabulary.
# Adding word 814000 to our question vocabulary.
# Adding word 815000 to our question vocabulary.
# Adding word 816000 to our question vocabulary.
# Adding word 817000 to our question vocabulary.
# Adding word 263000 to our answer vocabulary.
# Adding word 818000 to our question vocabulary.
# Adding word 819000 to our question vocabulary.
# Adding word 820000 to our question vocabulary.
# Adding word 264000 to our answer vocabulary.
# Adding word 821000 to our question vocabulary.
# Adding word 822000 to our question vocabulary.
# Adding word 265000 to our answer vocabulary.
# Adding word 823000 to our question vocabulary.
# Adding word 824000 to our question vocabulary.
# Adding word 266000 to our answer vocabulary.
# Adding word 825000 to our question vocabulary.
# Adding word 826000 to our question vocabulary.
# Adding word 827000 to our question vocabulary.
# Adding word 828000 to our question vocabulary.
# Adding word 267000 to our answer vocabulary.
# Adding word 829000 to our question vocabulary.
# Adding word 830000 to our question vocabulary.
# Adding word 831000 to our question vocabulary.
# Adding word 268000 to our answer vocabulary.
# Adding word 832000 to our question vocabulary.
# Adding word 833000 to our question vocabulary.
# Adding word 834000 to our question vocabulary.
# Adding word 269000 to our answer vocabulary.
# Adding word 835000 to our question vocabulary.
# Adding word 270000 to our answer vocabulary.
# Adding word 836000 to our question vocabulary.
# Adding word 837000 to our question vocabulary.
# Adding word 838000 to our question vocabulary.
# Adding word 271000 to our answer vocabulary.
# Adding word 839000 to our question vocabulary.
# Adding word 840000 to our question vocabulary.
# Adding word 841000 to our question vocabulary.
# Adding word 272000 to our answer vocabulary.
# Adding word 842000 to our question vocabulary.
# Adding word 843000 to our question vocabulary.
# Adding word 844000 to our question vocabulary.
# Adding word 273000 to our answer vocabulary.
# Adding word 845000 to our question vocabulary.
# Adding word 846000 to our question vocabulary.
# Adding word 847000 to our question vocabulary.
# Adding word 274000 to our answer vocabulary.
# Adding word 848000 to our question vocabulary.
# Adding word 849000 to our question vocabulary.
# Adding word 850000 to our question vocabulary.
# Adding word 851000 to our question vocabulary.
# Adding word 275000 to our answer vocabulary.
# Adding word 852000 to our question vocabulary.
# Adding word 853000 to our question vocabulary.
# Adding word 854000 to our question vocabulary.
# Adding word 276000 to our answer vocabulary.
# Adding word 855000 to our question vocabulary.
# Adding word 856000 to our question vocabulary.
# Adding word 857000 to our question vocabulary.
# Adding word 858000 to our question vocabulary.
# Adding word 277000 to our answer vocabulary.
# Adding word 859000 to our question vocabulary.
# Adding word 860000 to our question vocabulary.
# Adding word 861000 to our question vocabulary.
# Adding word 862000 to our question vocabulary.
# Adding word 863000 to our question vocabulary.
# Adding word 278000 to our answer vocabulary.
# Adding word 864000 to our question vocabulary.
# Adding word 865000 to our question vocabulary.
# Adding word 866000 to our question vocabulary.
# Adding word 279000 to our answer vocabulary.
# Adding word 867000 to our question vocabulary.
# Adding word 868000 to our question vocabulary.
# Adding word 869000 to our question vocabulary.
# Adding word 280000 to our answer vocabulary.
# Adding word 870000 to our question vocabulary.
# Adding word 871000 to our question vocabulary.
# Adding word 872000 to our question vocabulary.
# Adding word 281000 to our answer vocabulary.
# Adding word 873000 to our question vocabulary.
# Adding word 874000 to our question vocabulary.
# Adding word 282000 to our answer vocabulary.
# Adding word 875000 to our question vocabulary.
# Adding word 876000 to our question vocabulary.
# Adding word 877000 to our question vocabulary.
# Adding word 878000 to our question vocabulary.
# Adding word 283000 to our answer vocabulary.
# Adding word 879000 to our question vocabulary.
# Adding word 880000 to our question vocabulary.
# Adding word 881000 to our question vocabulary.
# Adding word 284000 to our answer vocabulary.
# Adding word 882000 to our question vocabulary.
# Adding word 883000 to our question vocabulary.
# Adding word 884000 to our question vocabulary.
# Adding word 885000 to our question vocabulary.
# Adding word 285000 to our answer vocabulary.
# Adding word 886000 to our question vocabulary.
# Adding word 887000 to our question vocabulary.
# Adding word 286000 to our answer vocabulary.
# Adding word 888000 to our question vocabulary.
# Adding word 889000 to our question vocabulary.
# Adding word 890000 to our question vocabulary.
# Adding word 287000 to our answer vocabulary.
# Adding word 891000 to our question vocabulary.
# Adding word 892000 to our question vocabulary.
# Adding word 893000 to our question vocabulary.
# Adding word 894000 to our question vocabulary.
# Adding word 288000 to our answer vocabulary.
# Adding word 895000 to our question vocabulary.
# Adding word 896000 to our question vocabulary.
# Adding word 897000 to our question vocabulary.
# Adding word 898000 to our question vocabulary.
# Adding word 899000 to our question vocabulary.
# Adding word 289000 to our answer vocabulary.
# Adding word 900000 to our question vocabulary.
# Adding word 901000 to our question vocabulary.
# Adding word 902000 to our question vocabulary.
# Adding word 903000 to our question vocabulary.
# Adding word 904000 to our question vocabulary.
# Adding word 290000 to our answer vocabulary.
# Adding word 905000 to our question vocabulary.
# Adding word 906000 to our question vocabulary.
# Adding word 907000 to our question vocabulary.
# Adding word 908000 to our question vocabulary.
# Adding word 291000 to our answer vocabulary.
# Adding word 909000 to our question vocabulary.
# Adding word 910000 to our question vocabulary.
# Adding word 911000 to our question vocabulary.
# Adding word 292000 to our answer vocabulary.
# Adding word 912000 to our question vocabulary.
# Adding word 913000 to our question vocabulary.
# Adding word 914000 to our question vocabulary.
# Adding word 915000 to our question vocabulary.
# Adding word 916000 to our question vocabulary.
# Adding word 293000 to our answer vocabulary.
# Adding word 917000 to our question vocabulary.
# Adding word 918000 to our question vocabulary.
# Adding word 919000 to our question vocabulary.
# Adding word 294000 to our answer vocabulary.
# Adding word 920000 to our question vocabulary.
# Adding word 921000 to our question vocabulary.
# Adding word 922000 to our question vocabulary.
# Adding word 923000 to our question vocabulary.
# Adding word 924000 to our question vocabulary.
# Adding word 295000 to our answer vocabulary.
# Adding word 925000 to our question vocabulary.
# Adding word 926000 to our question vocabulary.
# Adding word 927000 to our question vocabulary.
# Adding word 928000 to our question vocabulary.
# Adding word 296000 to our answer vocabulary.
# Adding word 929000 to our question vocabulary.
# Adding word 930000 to our question vocabulary.
# Adding word 931000 to our question vocabulary.
# Adding word 932000 to our question vocabulary.
# Adding word 933000 to our question vocabulary.
# Adding word 297000 to our answer vocabulary.
# Adding word 934000 to our question vocabulary.
# Adding word 935000 to our question vocabulary.
# Adding word 936000 to our question vocabulary.
# Adding word 937000 to our question vocabulary.
# Adding word 298000 to our answer vocabulary.
# Adding word 938000 to our question vocabulary.
# Adding word 939000 to our question vocabulary.
# Adding word 940000 to our question vocabulary.
# Adding word 299000 to our answer vocabulary.
# Adding word 941000 to our question vocabulary.
# Adding word 942000 to our question vocabulary.
# Adding word 943000 to our question vocabulary.
# Adding word 300000 to our answer vocabulary.
# Adding word 944000 to our question vocabulary.
# Adding word 945000 to our question vocabulary.
# Adding word 301000 to our answer vocabulary.
# Adding word 946000 to our question vocabulary.
# Adding word 302000 to our answer vocabulary.
# Adding word 947000 to our question vocabulary.
# Adding word 303000 to our answer vocabulary.
# Adding word 948000 to our question vocabulary.
# Adding word 949000 to our question vocabulary.
# Adding word 950000 to our question vocabulary.
# Adding word 951000 to our question vocabulary.
# Adding word 304000 to our answer vocabulary.
# Adding word 952000 to our question vocabulary.
# Adding word 953000 to our question vocabulary.
# Adding word 954000 to our question vocabulary.
# Adding word 955000 to our question vocabulary.
# Adding word 956000 to our question vocabulary.
# Adding word 305000 to our answer vocabulary.
# Adding word 957000 to our question vocabulary.
# Adding word 958000 to our question vocabulary.
# Adding word 959000 to our question vocabulary.
# Adding word 960000 to our question vocabulary.
# Adding word 306000 to our answer vocabulary.
# Adding word 961000 to our question vocabulary.
# Adding word 962000 to our question vocabulary.
# Adding word 963000 to our question vocabulary.
# Adding word 307000 to our answer vocabulary.
# Adding word 964000 to our question vocabulary.
# Adding word 965000 to our question vocabulary.
# Adding word 966000 to our question vocabulary.
# Adding word 308000 to our answer vocabulary.
# Adding word 967000 to our question vocabulary.
# Adding word 968000 to our question vocabulary.
# Adding word 969000 to our question vocabulary.
# Adding word 309000 to our answer vocabulary.
# Adding word 970000 to our question vocabulary.
# Adding word 971000 to our question vocabulary.
# Adding word 972000 to our question vocabulary.
# Adding word 973000 to our question vocabulary.
# Adding word 310000 to our answer vocabulary.
# Adding word 974000 to our question vocabulary.
# Adding word 975000 to our question vocabulary.
# Adding word 976000 to our question vocabulary.
# Adding word 977000 to our question vocabulary.
# Adding word 311000 to our answer vocabulary.
# Adding word 978000 to our question vocabulary.
# Adding word 979000 to our question vocabulary.
# Adding word 980000 to our question vocabulary.
# Adding word 312000 to our answer vocabulary.
# Adding word 981000 to our question vocabulary.
# Adding word 982000 to our question vocabulary.
# Adding word 983000 to our question vocabulary.
# Adding word 313000 to our answer vocabulary.
# Adding word 984000 to our question vocabulary.
# Adding word 314000 to our answer vocabulary.
# Adding word 985000 to our question vocabulary.
# Adding word 986000 to our question vocabulary.
# Adding word 315000 to our answer vocabulary.
# Adding word 987000 to our question vocabulary.
# Adding word 988000 to our question vocabulary.
# Adding word 316000 to our answer vocabulary.
# Adding word 989000 to our question vocabulary.
# Adding word 990000 to our question vocabulary.
# Adding word 991000 to our question vocabulary.
# Adding word 317000 to our answer vocabulary.
# Adding word 992000 to our question vocabulary.
# Adding word 993000 to our question vocabulary.
# Adding word 994000 to our question vocabulary.
# Adding word 995000 to our question vocabulary.
# Adding word 318000 to our answer vocabulary.
# Adding word 996000 to our question vocabulary.
# Adding word 997000 to our question vocabulary.
# Adding word 998000 to our question vocabulary.
# Adding word 999000 to our question vocabulary.
# Adding word 319000 to our answer vocabulary.
# Adding word 1000000 to our question vocabulary.
# Adding word 1001000 to our question vocabulary.
# Adding word 320000 to our answer vocabulary.
# Adding word 1002000 to our question vocabulary.
# Adding word 1003000 to our question vocabulary.
# Adding word 321000 to our answer vocabulary.
# Adding word 1004000 to our question vocabulary.
# Adding word 1005000 to our question vocabulary.

# %%
def convert_to_tensor(df, q_vocab, a_vocab):

    source_data = []
    target_data = []
    for i, r in df.iterrows():
        temp_indexed_question = [q_vocab.words[word] for word in r['question']]
        temp_question_tensor = torch.Tensor(temp_indexed_question).long().to(device).view(-1, 1)
        source_data.append(temp_question_tensor)
        
        temp_indexed_answer = [a_vocab.words[word] for word in r['answer']]
        temp_answer_tensor = torch.Tensor(temp_indexed_answer).long().to(device).view(-1, 1)
        target_data.append(temp_answer_tensor)
    
    return source_data, target_data

# %%
source_data, target_data = convert_to_tensor(data_df, q_v, a_v)

# %%
def train_test_split(SRC, TRG):
    
    '''
    Input: SRC, our list of questions from the dataset
            TRG, our list of responses from the dataset

    Output: Training and test datasets for SRC & TRG

    '''
    
    return SRC_train_dataset, SRC_test_dataset, TRG_train_dataset, TRG_test_dataset

# %%
class Encoder(nn.Module):
    
    def __init__(self, input_size, hidden_size, embedding_size, n_layers=1):
        super(Encoder, self).__init__()
        
        # self.embedding provides a vector representation of the inputs to our model
        # self.lstm, accepts the vectorized input and passes a hidden state
        
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers
        
        self.hidden = torch.zeros(1, 1, hidden_size)
        
        self.embedding = nn.Embedding(self.input_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.n_layers)
        
    
    def forward(self, x, hidden, cell):
        
        '''
        Inputs: x, the src vector
        Outputs: out, the encoder outputs
                hidden, the hidden state
                cell, the cell state
        '''
        out = self.embedding(x)
        out = out.view(1, 1, -1)
        out, (hidden, cell) = self.lstm(out, (hidden, cell))
        
        return out, hidden, cell

# %%
class Decoder(nn.Module):
      
    def __init__(self, hidden_size, output_size, embedding_size, n_layers=1):
        super(Decoder, self).__init__()
        
        # self.embedding provides a vector representation of the target to our model
        # self.lstm, accepts the embeddings and outputs a hidden state
        # self.ouput, predicts on the hidden state via a linear output layer     
        
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers
        
        self.embedding = nn.Embedding(self.output_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.n_layers)
        self.fc = nn.Linear(self.hidden_size, self.output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        
    def forward(self, x, hidden, cell):
        
        '''
        Inputs: x, the target vector
        Outputs: out, the prediction
                hidden, the hidden state
                cell, the cell state
        '''
        out = self.embedding(x)
        out = out.view(1, 1, -1)
        out, (hidden, cell) = self.lstm(out, (hidden, cell))
        out = self.fc(out[0])
        out = self.softmax(out)
        
        return out, hidden, cell

# %%
class Seq2Seq(nn.Module):
    
    def __init__(self, input_size, hidden_size, output_size, embedding_size, device, n_layers=1):
        super(Seq2Seq, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers
        self.device = device
        
        self.encoder = Encoder(self.input_size, self.hidden_size, self.embedding_size, self.n_layers)
        self.decoder = Decoder(self.hidden_size, self.output_size, self.embedding_size, self.n_layers)
    
    
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        trg_len = trg.shape[0]
        src_len = src.shape[0]
        
        nn_output = {
            'decoder_output':[]
        }
        
        # initial hidden and cell states
        hidden = torch.zeros([self.n_layers, 1, self.hidden_size]).to(self.device)
        cell = torch.zeros([self.n_layers, 1, self.hidden_size]).to(self.device)
        
        for idx in range(src_len):
            encoder_output, hidden, cell = self.encoder(src[idx], hidden, cell)
            
        decoder_input = torch.Tensor([[0]]).long().to(self.device)
        
        for idx in range(trg_len):
            decoder_output, hidden, cell = self.decoder(decoder_input, hidden, cell)
            nn_output['decoder_output'].append(decoder_output)
            
            #deploying teaching improvement
            if self.training:
                decoder_input = trg[idx] if random.random() > teacher_forcing_ratio else decoder_output.argmax(1)
            else:
                _, top_index = decoder_output.data.topk(1)
                decoder_input = top_index.squeeze().detach()
        
        
        return nn_output

# %%
learning_rate = 0.01
hidden_size = 64
embedding_size = 64
batch_size = 64
epochs = 3

# %%
seq2seq_model = Seq2Seq(q_v.count, hidden_size, a_v.count, embedding_size, device)

# %%
def training_function(source_data, target_data, model, epochs, batch_size, print_every, learning_rate, device):
    
    model.to(device)
    total_training_loss = 0
    total_validation_loss = 0
    loss = 0
    
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()
    
    #cross validation
    kf = KFold(n_splits=5, shuffle=True)
    
    for e, (train_idx, test_idx) in enumerate(kf.split(source_data), 1):
        model.train()
        for idx in range(0, len(train_idx)):
            src = source_data[idx]
            trg = target_data[idx]
            
            try:
                nn_output = model(src, trg)
            except RuntimeError:
                print("training")
                print("idx: ", idx)
                print("source_data: ", src)
                print("target_data: ", trg)
            
            current_loss = 0
            for (s, t) in zip(nn_output['decoder_output'], trg):
#                 try:
                current_loss += criterion(s, t)
#                 except RuntimeError:
#                     print("Training current Loss error")
#                     print("Criterion: ", criterion)                
                
            loss += current_loss
#           total_training_loss += (current_loss.item() / trg.size(0)) #cummulating loss from each iteration
#             try:
            total_training_loss += (current_loss / trg.size(0)) #cummulating loss from each iteration
#             except ZeroDivisionError:
#                 print('idx:', idx)
#                 print("target:", trg)
            
            if idx % batch_size == 0 or idx == (len(train_idx)-1):
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss = 0
                
                
        #validation
        model.eval()
        for idx in range(0, len(test_idx)):
            src = source_data[idx]
            trg = target_data[idx]
    
            try:
                nn_output = model(src, trg)
            except RuntimeError:
                print("validation")
                print("idx: ", idx)
                print("source_data: ", src)
                print("target_data: ", trg)
                
            current_loss = 0
            for (s, t) in zip(nn_output['decoder_output'], trg):
#                 try:
                current_loss += criterion(s, t)
#                 except RuntimeError:
#                     print("validation current Loss error")
#                     print("Criterion: ", criterion)
                
    #         total_validation_loss += (current_loss.item() / trg.size(0))
            total_validation_loss += (current_loss / trg.size(0))        

        if e % print_every == 0:
            training_loss_avg = total_training_loss / (len(train_idx)*print_every)
            validation_loss_avg = total_validation_loss / (len(test_idx)*print_every)
            print("{}/{} Epoch ---- Training Loss = {:.5f} ---- Validation Loss = {:.5f}".format(e, epochs, training_loss_avg, validation_loss_avg))
            total_training_loss = 0
            total_validation_loss = 0

# %%
training_function(source_data=source_data, target_data=target_data, model=seq2seq_model, print_every=1, epochs=epochs,
                  learning_rate=learning_rate, batch_size=batch_size, device=device)
# Out:
# 1/3 Epoch ---- Training Loss = 9.35387 ---- Validation Loss = 9.14088
# validation
# idx:  4671
# source_data:  tensor([[  12],
#         [  13],
#         [   3],
#         [ 155],
#         [  15],
#         [   3],
#         [ 851],
#         [   3],
#         [1144],
#         [4108],
#         [ 353],
#         [   8]], device='cuda:0')
# target_data:  tensor([[4008],
#         [3988]], device='cuda:0')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-6a0438c1d88b> in <module>
#       1 training_function(source_data=source_data, target_data=target_data, model=seq2seq_model, print_every=1, epochs=epochs,
# ----> 2                   learning_rate=learning_rate, batch_size=batch_size, device=device)
#
# <ipython-input-20-13d2f8bd292b> in training_function(source_data, target_data, model, epochs, batch_size, print_every, learning_rate, device)
#      66             for (s, t) in zip(nn_output['decoder_output'], trg):
#      67 #                 try:
# ---> 68                 current_loss += criterion(s, t)
#      69 #                 except RuntimeError:
#      70 #                     print("validation current Loss error")
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     209
#     210     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 211         return F.nll_loss(input, target, weight=self.weight, ignore_index=self.ignore_index, reduction=self.reduction)
#     212
#     213
#
# ~/.local/lib/python3.7/site-packages/torch/nn/functional.py in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2669     if size_average is not None or reduce is not None:
#    2670         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2671     return torch._C._nn.nll_loss_nd(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#    2672
#    2673
#
# RuntimeError: CUDA error: invalid resource handle
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
2+2

# %%
1+1+1

# %%
1+1+1+1

# %%
idx: 27633
target: tensor([], device='cuda:0', size=(0, 1), dtype=torch.int64)
idx: 55764
target: tensor([], device='cuda:0', size=(0, 1), dtype=torch.int64)
idx: 27633
target: tensor([], device='cuda:0', size=(0, 1), dtype=torch.int64)
idx: 55764
target: tensor([], device='cuda:0', size=(0, 1), dtype=torch.int64)
